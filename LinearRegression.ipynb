# %%
import random
import numpy as np
import matplotlib.pyplot as plt

# %%
random.seed(100)

# %%
x = np.random.uniform(-10, 10, size = 1000)**3

# %%
y = np.random.randn(1000) + 0.01 * x

# %%
a = plt.scatter(x, y)

# %%
fit = np.polyfit(x, y, 1)

# %%
x_bar = np.sum(x) / len(x)

# %%
y_bar = np.sum(y) / len(y)

# %%
x_bar, y_bar
# Out:
# (-2.2711694365222463, -0.012780152341537579)

# %% [markdown]
# ## calculating linear regression (with computing)

# %%
x_bar = np.mean(x)
y_bar = np.mean(y)
xx_bar = np.mean(x ** 2)
xy_bar = np.mean(x * y)

# %%
beta_1 = (x_bar * y_bar - xy_bar) / (x_bar ** 2 - xx_bar)

# %%
beta_0 = (y_bar - x_bar * ((x_bar * y_bar) - (xy_bar))/ (x_bar ** 2 - xx_bar))

# %%
y_hat = beta_0 + beta_1 * x

# %%
plt.scatter(x, y)
plt.scatter(x, y_hat)
plt.scatter(x_bar, y_bar)

# %% [markdown]
# ## linear regression class

# %%
class LinearRegression:
    def __init__(self):
        self.beta_0 = 0
        self.beta_1 = 0
    
    def fit(self, x, y):
        x_bar = np.mean(x)
        y_bar = np.mean(y)
        xx_bar = np.mean(x ** 2)
        xy_bar = np.mean(x * y)
        
        self.beta_1 = (x_bar * y_bar - xy_bar) / (x_bar ** 2 - xx_bar)
        self.beta_0 = (y_bar - x_bar * ((x_bar * y_bar) - (xy_bar))/ (x_bar ** 2 - xx_bar))
        
    def predict(self, x):
        y_hat = self.beta_0 + self.beta_1 * x
        return y_hat

# %%
# %%time

linear_regressor = LinearRegression()

linear_regressor.fit(x, y)

y_hat_from_lr_class = linear_regressor.predict(x)

plt.scatter(x, y)
plt.scatter(x, y_hat_from_lr_class)
plt.scatter(x_bar, y_bar)
# Out:
# Wall time: 20.9 ms

# %%
def get_r_squared(y, y_hat):
    return 1 - np.sum(np.square(y - y_hat)) / np.sum(np.square(y - np.mean(y)))

# %%
print(x[0], y[0])
# Out:
# -4.159864260208399 -1.0492966005105453

# %%
get_r_squared(y, linear_regressor.predict(x))
# Out:
# 0.935081184553813
